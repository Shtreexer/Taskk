# %%
! pip install opendatasets
! pip install opencv-python

# %%
import os

import opendatasets as od


import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %%
name = 'https://www.kaggle.com/datasets/utkarshsaxenadn/animal-image-classification-dataset'
od.download(name)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: aleksandrburak
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/utkarshsaxenadn/animal-image-classification-dataset
# ...
# 100%|██████████| 18.8G/18.8G [03:36<00:00, 93.0MB/s]

# %%
for path, sub_dir, filles  in os.walk('/content/animal-image-classification-dataset/Training Data/Training Data'):

    print(len(filles))
# Out:
# 0
# 2000
# 2000
# 2000
# 2000
# 2000
# 2000
# 2000
# 2000
# 2000
# 2000
# 2000
# 2000
# 2000
# 2000
# 2000

# %% [markdown]
# Dataset has 15 classes of animal species, each class contain 2000 image wich represent it's appearance. 75% will be used to train the model

# %%
class_list = ['Butterfly', 'Lizard', 'Cat', 'Hippo', 'Beetle', 'Elephant', 'Zebra', 'Cow', 'Gorilla', 'Panda', 'Spider', 'Mouse', 'Monkey', 'Dog', 'Tiger']
print(class_list)
# Out:
# ['Butterfly', 'Lizard', 'Cat', 'Hippo', 'Beetle', 'Elephant', 'Zebra', 'Cow', 'Gorilla', 'Panda', 'Spider', 'Mouse', 'Monkey', 'Dog', 'Tiger']

# %%
def show_example(path = None):
  img = mpimg.imread(path)
  imgplot = plt.imshow(img)

# %%
show_example(path='/content/animal-image-classification-dataset/Training Data/Training Data/Panda/Panda (1911).jpeg')

# %%
show_example(path='/content/animal-image-classification-dataset/Training Data/Training Data/Tiger/Tiger (1023).jpeg')

# %%
show_example(path='/content/animal-image-classification-dataset/Training Data/Training Data/Monkey/HM (121).jpeg')

# %%
show_example(path='/content/animal-image-classification-dataset/Training Data/Training Data/Beetle/Beetle-Train (1078).jpeg')

# %% [markdown]
# Original size of image 256x256x3, it will be reshape to 224x224x3
